# %% [markdown]
# ## Analytics in Action 📈

# %% [markdown]
# ### Objective 🎯:
# - Introduce analytics concepts
# - Types of analytics
# - How to approach any analytics problem?
# - Hands-on coding demo

# %% [markdown]
# ### 1. Introduction to Analytics

# %% [markdown]
# #### **"Do you think the success of an investment depends more on luck or data?" 🤔**

# %% [markdown]
# ![alt text](../static/money_podcast.png)

# %% [markdown]
# ##### So What is Analytics?
#
# - **Analytics is about uncovering insights from data to make better decisions.**
#
# - Examples of analytics in real life:
#     - Netflix recommending what to watch.
#     - Amazon predicting which product you’ll buy.
#     - Investors deciding where and when to put money.
#
#
# **Can you guess what chart is this?**
#
# <img src="../static/comodity_price.png" alt="Guess Which Comodity is it?" style="width:50%; height:50%"/>

# %% [markdown]
# ### 2. The 4 Types of Analytics 📊

# %% [markdown]
# ##### **Descriptive Analytics 🔙:**
# - What happened?
# - Example: "How much did gold cost on average last year?"

# %% [markdown]
# <img src="../static/gold_meme1.png" alt="Interesting truth!" style="width:70%; height:70%"/>

# %% [markdown]
# ##### **Diagnostic Analytics 🧐:**
# - Why did it happen?
# - Example: "Why did gold prices suddenly spike in 2021?"

# %% [markdown]
# <img src="../static/why_meme.png" alt="Interesting truth!" style="width:40%; height:40%"/>

# %% [markdown]
# ##### **Predictive Analytics 🔜:**
# - What will happen?
# - Example: "If gold prices rose during inflation in the past, will the same trend continue?"

# %% [markdown]
# <img src="../static/predictive_analytics.png" alt="Interesting truth!" style="width:50%; height:%0%"/>

# %% [markdown]
# ##### **Prescriptive Analytics 🔀:**
# - What should we do?
# - Example: "Given past data, should I invest in gold or anything else?"

# %% [markdown]
# ![alt text](../static/bitcoin.png)

# %% [markdown]
# ### How to Approach any Analytics Problem 🤷??
# ***This is a generic systematic approach which can be tailor-made to as per requirement***

# %% [markdown]
# #### 1. Define the Problem Clearly 📝

# %% [markdown]
# - What is the objective?
#     - Understand the business context or the goal behind the analysis.
#     - Example: “What drives sales for product X?” or “How can an investor optimize their portfolio?”
# - Who are the stakeholders?
#     - Identify who will use the insights and tailor your analysis accordingly.

# %% [markdown]
# #### 1.5 Generate Hypotheses 🧠

# %% [markdown]
# - What could be driving the outcomes?
#     - Think critically and creatively about potential reasons for observed behaviors or trends.
#     - Leverage Domain Knowledge:
# - Collaborate with stakeholders or SMEs (subject matter experts) to ensure hypotheses align with business realities.
# - Formulate Testable Statements:
#     - Example: "Gold prices increase during economic instability," or, "Quarterly volatility of silver is higher than gold."

# %% [markdown]
# #### 2. Understand the Data 💾

# %% [markdown]
# - What data is available?
#     - Check the type, source, and format of data. Examples: structured (tables, CSVs) or unstructured (text, images).
#     - What is missing?
# - Identify any gaps in the data and consider sourcing additional information if necessary.

# %% [markdown]
# #### 3. Formulate Analytics Questions 🧪

# %% [markdown]
# - Break the main problem into smaller questions, such as:
#     - Descriptive: What has happened so far?
#     - Diagnostic: Why did it happen?
#     - Predictive: What is likely to happen next?
#     - Prescriptive: What actions should be taken?

# %% [markdown]
# #### 4. Explore and Preprocess the Data 🔍

# %% [markdown]
# - EDA (Exploratory Data Analysis):
#     - Identify trends, correlations, and anomalies. Use tools like pandas and matplotlib for visualization.
# - Data Cleaning:
#     - Handle missing values, remove duplicates, and fix inconsistencies.
# - Data Transformation:
#     - Normalize, scale, and encode the data, depending on the requirements.

# %% [markdown]
# #### 4.5. Test the Hypotheses 🔬

# %% [markdown]
# - Validate hypotheses with data:
#     - Use statistical techniques (e.g., correlation analysis, regression) or visualization.
#     - Example: Plot inflation vs. gold prices to check correlation visually and calculate statistical significance.
# - Accept or Reject:
#     - If a hypothesis is rejected, refine it or explore alternative explanations.

# %% [markdown]
# #### 5. Select the Right Analytics Technique ✅

# %% [markdown]
# - Match the question to the method:
#     - Trend analysis → Descriptive analytics
#     - Root cause identification → Diagnostic analytics
#     - Forecasting → Predictive analytics
#     - Optimization → Prescriptive analytics
# - Examples of techniques:
#     - Statistical analysis, machine learning, hypothesis testing, or data visualization.

# %% [markdown]
# #### 6. Conduct the Analysis 🧮

# %% [markdown]
# - Apply the chosen techniques and document each step:
#     - Descriptive Statistics: Summarize mean, median, mode, etc.
#     - Modeling: Train machine learning models or fit statistical models.
#     - Visualization: Use charts to simplify insights for stakeholders.
#     - There are other techniques which can be statistical, optimization, etc.

# %% [markdown]
# #### 7. Validate Insights and Results 📐

# %% [markdown]
# - Are results accurate?
#     - Test models on unseen data to evaluate accuracy.
# - Cross-check findings:
#     - Ensure alignment with domain knowledge and business context.

# %% [markdown]
# #### 8. Communicate Results Effectively 🎙️

# %% [markdown]
# - Simplify technical findings for stakeholders:
#     - Visuals: Use dashboards, charts, and infographics.
#     - Stories: Relate findings to business goals or user stories.
# - Be ready to answer questions and provide actionable recommendations.

# %% [markdown]
# #### 9. Suggest Actions and Solutions 🛣️

# %% [markdown]
# - Translate analytics into business impact:
#     - Example: "Invest 60% in gold and 40% in silver for lower risk, considering past trends."
#     -  Example: "Implement predictive maintenance to reduce costs by X%."

# %% [markdown]
# #### 10. Iterate and Monitor ♾️🚨🕵🏻

# %% [markdown]
# - Analytics is iterative. Keep improving your models and refine insights as new data becomes available.
# - Set up feedback loops to assess the effectiveness of implemented actions.

# %% [markdown]
# #### Tips for a Smooth Approach 📌

# %% [markdown]
# 1. Start Simple: Focus on key questions first and build complexity step-by-step.
# 2. Be Visual: Use graphs to uncover trends and engage stakeholders.
# 3. Involve Stakeholders: Get regular feedback to ensure alignment with goals.
# 4. Keep Learning: Evolve your skills with new tools and techniques as analytics advances.

# %% [markdown]
# ## Hands-On Code 💻

# %%
# import yfinance as yf

from datetime import datetime

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Fetch gold and silver ETF prices in INR
# gold_etf = yf.download("GOLDBEES.NS", start="2021-01-01", end="2024-12-31")
# silver_etf = yf.download("SILVERBEES.NS", start="2021-01-01", end="2024-12-31")

# %%
data = pd.read_csv('../data/external/gold_silver.csv', index_col='Date')

# Convert the index to type datetime
data.index = pd.to_datetime(data.index)

# %% [markdown]
# ### Let's do basic descriptive analytics

# %%
data.describe()
# Out:
#              gold      silver
# count  715.000000  715.000000
# mean    51.738028   71.272601
# std      6.973240   10.031263
# min     41.599998   52.270000
# 25%     44.900002   64.564999
# 50%     50.650002   70.070000
# 75%     58.650000   77.950001
# max     67.019997   96.110001

# %% [markdown]
# ### Historical Price Trends 📉
# Let's visualize the historical closing prices of **gold** and **silver**.

# %%
# Plot historical prices
plt.figure();
data.plot(title="Gold & Silver BEES Closing Prices", figsize=(10,5), color=['gold', 'silver']);
plt.xlabel("Date");
plt.ylabel("Price");
plt.show();

# %% [markdown]
# ### Calculating Daily Percent Change in prices

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pct_change.html

# %%
data['silver_ret'] = data['silver'].pct_change()
data['gold_ret'] = data['gold'].pct_change()

# %%
data.head()
# Out:
#                  gold     silver  silver_ret  gold_ret
# Date
# 2022-02-04  41.599998  60.959599         NaN       NaN
# 2022-02-07  41.630001  61.770000    0.013294  0.000721
# 2022-02-08  41.820000  62.279999    0.008256  0.004564
# 2022-02-09  41.990002  62.770000    0.007868  0.004065
# 2022-02-10  42.169998  62.799999    0.000478  0.004287

# %%
data.describe()
# Out:
#              gold      silver  silver_ret    gold_ret
# count  715.000000  715.000000  714.000000  714.000000
# mean    51.738028   71.272601    0.000563    0.000632
# std      6.973240   10.031263    0.014018    0.007580
# min     41.599998   52.270000   -0.044045   -0.030928
# 25%     44.900002   64.564999   -0.007301   -0.003335
# 50%     50.650002   70.070000   -0.000060    0.000379
# 75%     58.650000   77.950001    0.008426    0.004796
# max     67.019997   96.110001    0.073467    0.035507

# %% [markdown]
# #### Lets see how gold silver prices and their returns corelated?

# %%
# Plot heatmap of correlation matrix for gold silver prices
plt.figure(figsize=(5,4))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Gold-Silver Price Correlation")
plt.show()

# %% [markdown]
# ##### Why gold silver price correlation is not same as gold silver returns correlation?

# %% [markdown]
# - While gold and silver prices generally move together, their price correlation isn't identical to their returns correlation because silver tends to be more volatile than gold.
# - When the price of gold moves, the price of silver can move significantly more, leading to a larger percentage change (return) in silver compared to gold.
# - Even if the direction of movement is the same; this difference in volatility creates a disparity between the simple price correlation and the return correlation.

# %% [markdown]
# ### Let's analyze if there are spikes in gold prices?
# - If we find spikes, let's try to find out the reason -- Why it spiked?

# %%
from scipy.stats import zscore

# Detect spikes using Z-score (spike if Z-score > 3)
data['gold_z_score'] = zscore(data['gold_ret'].dropna())
gold_spikes = data[data['gold_z_score'] > 3]

# %%
gold_spikes.sort_values('gold_z_score', ascending=False)
# Out:
#                  gold     silver  silver_ret  gold_ret  gold_z_score
# Date
# 2022-02-24  44.619999  66.980003    0.045256  0.035507      4.604033
# 2022-03-07  46.000000  70.370003    0.042210  0.030235      3.908056
# 2024-04-01  58.320000  74.029999    0.022231  0.030207      3.904298
# 2023-03-13  48.820000  63.099998    0.030036  0.029306      3.785441
# 2024-05-10  61.919998  83.010002    0.030540  0.024826      3.193995

# %% [markdown]
# #### WHY ?? WHY ?? WHY ??
# *Let's see if you can search over the Internet!*

# %% [markdown]
# ![Gold Spike Reasons](../static/gold_spikes_reason.png)

# %%
data.drop(columns=['gold_ret', 'silver_ret', 'gold_z_score'], inplace=True)

# %% [markdown]
# # Analyze using Simulation 🎲

# %% [markdown]
# ### Step 1: Calculate Returns 🔢
# Instead of raw returns, we can use **logarithmic returns**

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shift.html

# %%
# Compute returns without pct_change()
returns = ((data - data.shift(1)) / data.shift(1)).dropna() # Alternate for pct_change()

# Compute log returns = ln(previous day/current day)
log_returns = np.log(data / data.shift(1)).dropna()

# Display first few returns
print('Simple Returns')
display(returns.head())
print('Log Returns')
display(log_returns.head())
# Out:
# Simple Returns
#                 gold    silver
# Date
# 2022-02-07  0.000721  0.013294
# 2022-02-08  0.004564  0.008256
# 2022-02-09  0.004065  0.007868
# 2022-02-10  0.004287  0.000478
# 2022-02-11  0.000474 -0.007006
# Log Returns
#                 gold    silver
# Date
# 2022-02-07  0.000721  0.013206
# 2022-02-08  0.004554  0.008223
# 2022-02-09  0.004057  0.007837
# 2022-02-10  0.004277  0.000478
# 2022-02-11  0.000474 -0.007031

# %%
# Plot historical prices
plt.figure(figsize=(10,5));
log_returns.plot(title="Gold & Silver BEES Daily Log Returns", 
             figsize=(10,5), color=['gold', 'silver'], ls=':');
# plt.Line2D.set_linestyle(ls='.');
plt.xlabel("Date");
plt.ylabel("Price");
plt.show();

# %%
# Plot historical prices
plt.figure(figsize=(10,5));
returns.plot(title="Gold & Silver BEES Daily Log Returns", 
             figsize=(10,5), color=['gold', 'silver'], ls=':');
# plt.Line2D.set_linestyle(ls='.');
plt.xlabel("Date");
plt.ylabel("Price");
plt.show();

# %% [markdown]
# #### So what exactly is the difference 🥴?????

# %% [markdown]
# ##### Cool stuffs about log returns
# 1. Log returns can be added across time periods.
# 2. Log returns can be easily converted back into simple returns
# 3. Log returns follow normal distribution

# %%
temp = [
    {'time': 0, 'price': 100},
    {'time': 1, 'price': 120},
    {'time': 2, 'price': 100}, 
]

temp = pd.DataFrame(temp)

# %%
temp
# Out:
#    time  price
# 0     0    100
# 1     1    120
# 2     2    100

# %%
temp['price'].shift(1)
# Out:
# 0      NaN
# 1    100.0
# 2    120.0
# Name: price, dtype: float64

# %%
temp['ret'] =  (temp['price'] - temp['price'].shift(1)) / temp['price'].shift(1)
temp['pct_change'] = temp['price'].pct_change()
temp['log_ret'] = np.log(temp['price'] / temp['price'].shift(1))

# %%
temp
# Out:
#    time  price       ret  pct_change   log_ret
# 0     0    100       NaN         NaN       NaN
# 1     1    120  0.200000    0.200000  0.182322
# 2     2    100 -0.166667   -0.166667 -0.182322

# %%
# ret = (e^log_ret) - 1
np.exp(temp['log_ret']) - 1
# Out:
# 0         NaN
# 1    0.200000
# 2   -0.166667
# Name: log_ret, dtype: float64

# %%
sns.kdeplot(log_returns);
plt.show();

# %% [markdown]
# ## Step 2: Compute Statistics 📊
# We need:
# - **Mean return** (μ): Average daily return.
# - **Volatility** (σ): Standard deviation of daily returns.
# - **Correlation** (ρ): Relationship between gold and silver price movements.

# %%
# Compute statistics
mu = log_returns.mean()
sigma = log_returns.std()
correlation_matrix = log_returns.corr()

# Print results
print("Mean Returns:\n", mu)
print("\nVolatility:\n", sigma)
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Mean Returns:
#  gold      0.000603
# silver    0.000465
# dtype: float64
#
# Volatility:
#  gold      0.007571
# silver    0.013989
# dtype: float64
#
# Correlation Matrix:
#              gold    silver
# gold    1.000000  0.762477
# silver  0.762477  1.000000

# %% [markdown]
# ## Step 3: Visualizing Correlation 🔗
# Let's plot a heatmap to understand the correlation between gold and silver returns.

# %%
# Plot heatmap of correlation matrix for gold silver prices
plt.figure(figsize=(5,4))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Gold-Silver Price Correlation")
plt.show()


# Plot heatmap of correlation matrix gold silver returns
plt.figure(figsize=(5,4))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Gold-Silver Return Correlation")
plt.show()

# %% [markdown]
# ## Step 4: Monte Carlo GBM Simulation 🎲
# ### The GBM formula:
# $$
# \ [
#     S_{t} = S_{t-1} \times e^{(\mu - 0.5 \sigma^2) \Delta t \space + \space \sigma \sqrt{\Delta t} Z}
# \ ]
# \newline
# \ [
#     S_{t} = S_{t-1} \times e^{drift\space + \space diffusion}
# \ ]
#
# $$
# Where:
# $$ \ ( S_{t-1} \ ) = Previous \space price $$
# $$ \ ( \mu \ ) = Expected \space return $$
# $$ \ ( \sigma \ ) = Volatility $$
# $$ \ ( \Delta t \ ) = Time \space step (1 day) $$
# $$ \ ( Z \ ) = Random \space normal \space variable $$
#
# ### Key Additions:
# - **Cholesky Decomposition** to generate correlated random values.
# - Cholesky decomposition is a mathematical technique that allows you to break down a correlation matrix (representing the relationships between multiple variables) into a lower triangular matrix and its conjugate transpose
# - It enables the generation of correlated random variables by transforming a set of uncorrelated variables using this matrix;
# - Essentially, it lets you "build" correlated data from a set of independent variables based on the specified correlation structure.

# %%
# Simulation parameters
T, dt, n_sim = 3 * 252, 1, 1000  # 3 years, 252 trading days/year, 1000 simulations
S0 = data.iloc[-1].values  # Last known prices
L = np.linalg.cholesky(correlation_matrix.values)  # Cholesky decomposition for correlation

# Initialize paths
paths = np.zeros((T, 2, n_sim))
paths[0, :, :] = S0.reshape(-1, 1)

# Simulate correlated GBM paths
np.random.seed(42)
for t in range(1, T):
    Z = np.random.randn(2, n_sim)  # Independent normal variables
    Z_corr = L @ Z  # Apply correlation
    drift = (mu - 0.5 * sigma**2) * dt
    diffusion = sigma.values[:, None] * np.sqrt(dt) * Z_corr
    paths[t] = paths[t - 1] * np.exp(drift.values[:, None] + diffusion)

print("Monte Carlo Simulation Completed! ✅")
# Out:
# Monte Carlo Simulation Completed! ✅

# %%
correlation_matrix.values
# Out:
# array([[1.        , 0.76247655],
#        [0.76247655, 1.        ]])

# %%
L
# Out:
# array([[1.        , 0.        ],
#        [0.76247655, 0.64701585]])

# %%
Z
# Out:
# array([[-2.08371407, -1.31824339, -0.71223325, ..., -1.28593988,
#         -0.92918227,  0.00924799],
#        [-0.48703904,  0.24640275, -0.15459264, ..., -2.70854384,
#          1.37552082, -0.52959601]])

# %%
Z_corr
# Out:
# array([[-2.08371407, -1.31824339, -0.71223325, ..., -1.28593988,
#         -0.92918227,  0.00924799],
#        [-1.9039051 , -0.84570319, -0.64308504, ..., -2.7329698 ,
#          0.18150408, -0.33560564]])

# %% [markdown]
# ## Step 5: Simulated Gold & Silver Price Paths 📈
# Let's plot a few **random** simulations for gold and silver.

# %%
plt.figure(figsize=(10,5))
plt.plot(paths[:,0,:10], alpha=0.6)  # First 10 gold simulations
plt.title("Simulated Gold Prices Over 3 Years")
plt.xlabel("Days")
plt.ylabel("Price")
plt.show()

plt.figure(figsize=(10,5))
plt.plot(paths[:,1,:10], alpha=0.6)  # First 10 silver simulations
plt.title("Simulated Silver Prices Over 3 Years")
plt.xlabel("Days")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## Step 6: Portfolio Simulation 💰
# We assume:
# - **70% allocation in gold**
# - **30% allocation in silver**
#
# The total portfolio value is:
# \[
# Portfolio_t = 0.7 \times Gold_t + 0.3 \times Silver_t
# \]

# %%
# Compute portfolio paths
portfolio = 0.7 * paths[:, 0, :] + 0.3 * paths[:, 1, :]

# Plot simulated portfolio paths
plt.figure(figsize=(10,5))
plt.plot(portfolio[:, :10], alpha=0.6)
plt.title("Simulated Portfolio Value (70% Gold, 30% Silver)")
plt.xlabel("Days")
plt.ylabel("Portfolio Value")
plt.show()

# %% [markdown]
# ### Summary & Next Steps 🚀
# 🎯 We successfully simulated **future gold & silver prices** and built a **correlated Monte Carlo simulation**.
#
# ### Key Takeaways:
# ✅ Used **historical data** to calculate returns, volatility, and correlation.
# ✅ Simulated **future price paths** using **Geometric Brownian Motion (GBM)**.
# ✅ Incorporated **correlation** between **gold and silver** using **Cholesky decomposition**.
# ✅ Built a **70-30 gold-silver portfolio** and simulated its future performance.
#
# ### **Next Steps**
# 1. Try different **portfolio allocations** (e.g., 50-50, 80-20).
# 2. Simulate different **investment periods** (e.g., 5 years).
# 3. Implement **risk measures** like VaR (Value at Risk).
# 4. Use **real-world market data APIs** instead of Excel files.

# %%
pd.DataFrame(paths[:, 0, :])
# Out:
#             0          1          2          3          4          5    \
# 0     64.000000  64.000000  64.000000  64.000000  64.000000  64.000000
# 1     64.278071  63.969789  64.351587  64.779492  63.923363  63.923371
# 2     63.987083  63.936564  64.003427  64.665775  63.049647  64.063490
# 3     63.606657  63.958205  64.048955  64.934897  62.436388  64.388549
# 4     63.108645  63.689998  63.630300  64.703210  62.371068  64.835210
# ..          ...        ...        ...        ...        ...        ...
# 751  115.660401  78.883789  85.433346  95.821174  89.737959  93.815414
# 752  116.102203  79.025164  86.527777  94.774505  89.488098  93.865491
# 753  115.587415  79.204942  86.626264  94.560238  90.091336  93.456929
# 754  114.142362  79.535395  87.927597  94.947630  90.085010  94.500756
# 755  112.420320  78.790781  87.504994  94.199776  90.462175  95.138789
#
#             6           7          8           9    ...         990  \
# 0     64.000000   64.000000  64.000000   64.000000  ...   64.000000
# 1     64.807054   64.409957  63.809573   64.300387  ...   64.137902
# 2     64.844899   64.049517  64.165729   64.795681  ...   64.915813
# 3     63.567172   63.781432  63.965703   65.144555  ...   63.928870
# 4     63.449242   63.056525  64.557321   64.770195  ...   64.251061
# ..          ...         ...        ...         ...  ...         ...
# 751  158.836343  114.242879  85.775135  168.566808  ...  114.751404
# 752  159.308969  114.240170  86.019346  166.840922  ...  115.513793
# 753  160.824648  113.797985  87.055234  168.163681  ...  114.178522
# 754  160.852325  115.264607  86.187754  167.583568  ...  113.854691
# 755  160.862073  115.792806  86.562997  169.846756  ...  114.178964
#
#            991        992         993         994         995         996  \
# 0    64.000000  64.000000   64.000000   64.000000   64.000000   64.000000
# 1    63.054483  63.917060   63.706988   63.552999   63.900646   64.914342
# 2    63.379006  63.988693   63.641274   63.132873   63.974897   65.078536
# 3    63.744329  63.969849   63.951699   62.855542   63.987945   65.467626
# 4    64.247390  64.466657   64.510725   62.592000   63.880500   65.887781
# ..         ...        ...         ...         ...         ...         ...
# 751  97.596485  89.075201  123.034461  122.241871   97.212213  100.102684
# 752  97.864412  89.355998  122.031315  123.297249   98.192707   99.940168
# 753  97.185826  88.702691  123.014764  124.238604   98.234401  100.255438
# 754  96.761046  88.726190  124.336547  124.195099   99.546705   99.924750
# 755  95.549262  88.249475  125.926522  125.778584  100.615934   99.911080
#
#             997         998        999
# 0     64.000000   64.000000  64.000000
# 1     64.348252   63.760456  64.315004
# 2     63.782745   63.958729  64.276373
# 3     65.341421   64.388212  63.901692
# 4     65.118443   64.422734  64.131757
# ..          ...         ...        ...
# 751  105.264768  120.882166  69.241026
# 752  105.184068  120.659069  69.655192
# 753  105.323660  119.926588  69.818930
# 754  106.126923  120.649713  69.551295
# 755  105.159075  119.872775  69.596148
#
# [756 rows x 1000 columns]

# %%
pd.DataFrame(paths[:, 1, :])
# Out:
#             0          1          2           3           4           5    \
# 0     84.949997  84.949997  84.949997   84.949997   84.949997   84.949997
# 1     86.521565  85.569078  85.616494   85.868701   85.306608   85.071651
# 2     84.461096  84.805630  84.609709   87.093938   84.053905   84.271875
# 3     83.396980  84.461187  83.292246   87.305002   83.419226   83.864496
# 4     83.030057  82.585920  83.025128   86.644548   83.794289   85.245116
# ..          ...        ...        ...         ...         ...         ...
# 751  207.938573  90.470362  64.545033  122.285884  112.417505  103.575182
# 752  209.070423  91.270818  65.758394  120.416311  112.458033  103.907446
# 753  205.922406  90.570421  66.096322  120.358088  113.996313  102.666729
# 754  198.356416  91.127917  67.732032  122.629653  114.869220  103.983756
# 755  193.214022  90.089219  67.150070  121.829750  115.703661  105.295995
#
#             6           7           8           9    ...         990  \
# 0     84.949997   84.949997   84.949997   84.949997  ...   84.949997
# 1     87.127865   86.173657   85.363776   85.061318  ...   85.789539
# 2     87.545244   84.268757   86.844586   85.582048  ...   85.897036
# 3     85.898523   84.105711   85.852723   86.083414  ...   84.435776
# 4     86.891610   83.745202   88.001042   86.472106  ...   85.933670
# ..          ...         ...         ...         ...  ...         ...
# 751  183.293030  117.230014  122.421609  229.591115  ...  100.175857
# 752  185.257984  116.476237  121.787209  225.342913  ...   99.970957
# 753  187.997145  114.954289  123.850591  227.880058  ...   97.999160
# 754  188.041570  116.925840  123.542927  226.609294  ...   97.929392
# 755  188.456606  118.809730  121.717032  233.317142  ...   95.850597
#
#             991         992         993         994         995         996  \
# 0     84.949997   84.949997   84.949997   84.949997   84.949997   84.949997
# 1     83.720099   85.674422   84.907840   84.345977   85.551415   86.605599
# 2     83.931663   84.251733   85.325060   81.977852   85.675635   85.257326
# 3     84.811449   83.422304   86.278135   82.073913   85.795377   86.839533
# 4     85.699105   85.559012   88.024347   81.032893   87.283085   87.846533
# ..          ...         ...         ...         ...         ...         ...
# 751  108.661334  141.115463  147.698701  210.705496  128.540246  100.304760
# 752  108.586011  141.952436  146.440152  217.130173  130.159252  100.359191
# 753  107.497698  140.115270  149.880487  217.862763  130.028454  101.339579
# 754  108.443778  139.709619  153.061846  212.185322  133.377563   99.027541
# 755  108.465640  139.861361  156.826209  218.298297  135.503873   98.335045
#
#            997         998        999
# 0    84.949997   84.949997  84.949997
# 1    84.883795   84.340434  84.927239
# 2    83.555075   85.941538  85.095150
# 3    85.460769   87.085336  83.470960
# 4    84.372387   88.425622  85.449486
# ..         ...         ...        ...
# 751  86.675502  170.923474  48.858821
# 752  86.758688  171.530471  48.805605
# 753  86.520936  167.712297  48.128738
# 754  87.916561  167.855763  47.786374
# 755  84.649849  168.344263  47.580007
#
# [756 rows x 1000 columns]

# %%
p = pd.DataFrame(portfolio)

# %%
p
# Out:
#             0          1          2           3          4          5    \
# 0     70.284999  70.284999  70.284999   70.284999  70.284999  70.284999
# 1     70.951119  70.449575  70.731059   71.106255  70.338336  70.267855
# 2     70.129287  70.197284  70.185312   71.394224  69.350924  70.126006
# 3     69.543754  70.109100  69.821942   71.645929  68.731239  70.231333
# 4     69.085068  69.358774  69.448748   71.285611  68.798035  70.958182
# ..          ...        ...        ...         ...        ...        ...
# 751  143.343853  82.359761  79.166852  103.760587  96.541823  96.743344
# 752  143.992669  82.698860  80.296962  102.467047  96.379078  96.878077
# 753  142.687912  82.614586  80.467282  102.299593  97.262829  96.219869
# 754  139.406578  83.013152  81.868928  103.252237  97.520273  97.345656
# 755  136.658431  82.180313  81.398516  102.488768  98.034621  98.185951
#
#             6           7          8           9    ...         990  \
# 0     70.284999   70.284999  70.284999   70.284999  ...   70.284999
# 1     71.503297   70.939067  70.275834   70.528666  ...   70.633393
# 2     71.655003   70.115289  70.969386   71.031591  ...   71.210180
# 3     70.266577   69.878716  70.531809   71.426213  ...   70.080942
# 4     70.481953   69.263128  71.590437   71.280768  ...   70.755844
# ..          ...         ...        ...         ...  ...         ...
# 751  166.173349  115.139019  96.769077  186.874100  ...  110.378740
# 752  167.093674  114.910990  96.749705  184.391519  ...  110.850942
# 753  168.976397  114.144876  98.093841  186.078594  ...  109.324714
# 754  169.009099  115.762977  97.394306  185.291285  ...  109.077101
# 755  169.140433  116.697884  97.109207  188.887872  ...  108.680454
#
#             991         992         993         994         995         996  \
# 0     70.284999   70.284999   70.284999   70.284999   70.284999   70.284999
# 1     69.254168   70.444268   70.067243   69.790893   70.395876   71.421719
# 2     69.544803   70.067605   70.146410   68.786367   70.485118   71.132173
# 3     70.064465   69.805585   70.649630   68.621053   70.530175   71.879198
# 4     70.682905   70.794363   71.564812   68.124268   70.901275   72.475407
# ..          ...         ...         ...         ...         ...         ...
# 751  100.915940  104.687279  130.433733  148.780958  106.610623  100.163307
# 752  101.080892  105.134930  129.353966  151.447126  107.782670  100.065875
# 753  100.279388  104.126465  131.074481  152.325852  107.772617  100.580680
# 754  100.265866  104.021219  132.954137  150.592166  109.695962   99.655587
# 755   99.424175  103.733041  135.196428  153.534498  111.082315   99.438270
#
#             997         998        999
# 0     70.284999   70.284999  70.284999
# 1     70.508915   69.934450  70.498675
# 2     69.714444   70.553572  70.522006
# 3     71.377226   71.197349  69.772472
# 4     70.894626   71.623601  70.527076
# ..          ...         ...        ...
# 751   99.687989  135.894559  63.126364
# 752   99.656454  135.920489  63.400316
# 753   99.682843  134.262301  63.311873
# 754  100.663814  134.811528  63.021818
# 755   99.006307  134.414221  62.991306
#
# [756 rows x 1000 columns]

# %%
final_return_paths = p.iloc[-1, :]

# %%
final_return_paths.describe()
# Out:
# count    1000.000000
# mean      105.591808
# std        26.816047
# min        47.680007
# 25%        87.306195
# 50%       102.225116
# 75%       121.104436
# max       234.966387
# Name: 755, dtype: float64

# %%
np.percentile(final_return_paths, 0.05)
# Out:
# np.float64(50.508549045678784)
